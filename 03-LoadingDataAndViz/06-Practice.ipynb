# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Reproduce the graphs below using Seaborn, Matplotlib, or a combination or both (I've made each of the plots using both)

# %%
df = sns.load_dataset('penguins')
df = df.dropna()

# %%
df.head(2)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female

# %% [markdown]
# ---

# %% [markdown]
# 1. Scatterplot

# %%
## Code:

# %%
## DO NOT RUN THE CELL OR EXAMPLE PLOT WILL DISAPPEAR

# %% [markdown]
# ---

# %% [markdown]
# 2. Boxplots

# %%
## Code:

# %%
## DO NOT RUN THE CELL OR EXAMPLE PLOT WILL DISAPPEAR

# %% [markdown]
# ---

# %% [markdown]
# 3. Scatter with Regression Line

# %%
## Code:

# %%
## DO NOT RUN THE CELL OR EXAMPLE PLOT WILL DISAPPEAR

# %% [markdown]
# ---

# %% [markdown]
# 4. Scatter with Lowess Line

# %%
## Code:

# %%
## DO NOT RUN THE CELL OR EXAMPLE PLOT WILL DISAPPEAR

# %% [markdown]
# ---

# %% [markdown]
# 5. Histogram

# %%
## Code:

# %%
## DO NOT RUN THE CELL OR EXAMPLE PLOT WILL DISAPPEAR

# %% [markdown]
# ---

# %% [markdown]
# 6. Histogram with subplots

# %%
## DO NOT RUN THE CELL OR EXAMPLE PLOT WILL DISAPPEAR

# %% [markdown]
# ---

# %% [markdown]
# 7. Correlation Heatmap

# %%
## Code:

# %%
## DO NOT RUN THE CELL OR EXAMPLE PLOT WILL DISAPPEAR
## (this used palette='YlGnBu')

# %% [markdown]
# ---
# Try practicing other types of plots, such as violin, stripplot, barchart, etc.
